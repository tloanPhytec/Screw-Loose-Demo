# %% [markdown]
# <a href="https://colab.research.google.com/github/tloanPhytec/Screw-Loose-Demo/blob/main/ScrewLooseDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Extract the dataset
# !unzip -q "/home/ubuntu/Fastener Object Detection.v1i.yolov8.zip" -d /content/dataset

# 2. Fix Roboflow's relative paths for Colab
import yaml
with open('/content/dataset/data.yaml', 'r') as f:
    data = yaml.safe_load(f)
data['path'] = '/content/dataset'
data['train'] = 'train/images'
data['val'] = 'valid/images'
with open('/content/dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

# 3. Install Ultralytics and Train
# !pip install -q ultralytics
# !yolo train data=/content/dataset/data.yaml model=yolov8n.pt epochs=50 imgsz=640
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 8.6 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# ...
# Ultralytics 8.4.154 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')

# %%
# !yolo export model=./runs/detect/train/weights/best.pt format=onnx opset=12
# Out:
# Ultralytics 8.4.154 🚀 Python-3.13.15 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.13.15 environment at: /usr
# Resolved 12 packages in 368ms
# Prepared 4 packages in 604ms
# Installed 4 packages in 253ms
#  + colorama==0.4.6
#  + onnx==1.22.0
#  + onnxruntime==1.30.0
#  + onnxslim==0.1.96
#
# requirements: AutoUpdate success ✅ 1.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.onnx')
